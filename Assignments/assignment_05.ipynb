# %% [markdown]
# ## Assignment 05
# Date - 07/03/2026

# %% [markdown]
#  **Sales Data Analysis Dashboard**

# %% [markdown]
# <img src="./assignment_05_ss/Screenshot 2026-03-07 111559.png"/>

# %% [markdown]
# **Explanation**

# %% [markdown]
# - Sales Distribution by Region (Pie Chart): pie chart show how total sales are distributed across different regions. North has the highest sales with 1.37M (27.29%), followed by East (1.26M), West (1.24M), and South (1.15M).
#
# - Region Filter: allows users to filter and analyze sales data based on a specific region.
#
# - Product Filter: helps users focus on sales data for a particular product category.
#
# - Total Sales (KPI Card): This card displays the overall sales amount of 5.02M, giving a quick summary of total sales performance.
#
# - Total Sales by Product (Bar Chart): This chart compares sales across product categories. Clothing has the highest sales, followed by Furniture, Electronics, and Food, showing which products contribute most to revenue.
